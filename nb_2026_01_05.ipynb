# %% [markdown]
# <a href="https://colab.research.google.com/github/SafaaMahbub/scratchpad/blob/main/nb_2026_01_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ds4e/get_data
# %run ./get_data/get_data.py
# Out:
# Cloning into 'get_data'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 4.17 KiB | 4.17 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %% [markdown]
# OK, let's see if this saves back the way I expect.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,3,5])
y = np.log(x)

plt.plot(x,y)
plt.show()

# %%
! git clone https://github.com/ds4e/scratchpad
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 27 (delta 2), reused 1 (delta 1), pack-reused 23 (from 1)
# Receiving objects: 100% (27/27), 29.15 KiB | 1.12 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import urllib.request
import os
import zipfile
import os

def download_data(force=False):
    """Download and extract course data from Zenodo."""

    zip_path = 'data.zip'
    data_dir = './data'

    if not os.path.exists(zip_path) or force:
        print("Downloading course data...")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/18235955/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")

    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")

    return data_dir


if __name__ == "__main__":
    download_data()

# %%
import pandas as pd


df = pd.read_csv('/content/data/sharks.csv', encoding = 'latin1')
df.head()
# Out:
# /tmp/ipython-input-3080941519.py:4: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data/sharks.csv', encoding = 'latin1')
#    index   Case Number                  Date    Year        Type      Country  \
# 0      0    2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1      1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2      2    2020.01.17           17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3      3    2020.01.16           16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4      4    2020.01.13           13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# ...

# %%
df.shape
# Out:
# (6462, 257)

# %%
df.dtypes
# Out:
# index             int64
# Case Number      object
# Date             object
# Year            float64
# Type             object
#                  ...
# Unnamed: 251    float64
# Unnamed: 252    float64
# Unnamed: 253    float64
# Unnamed: 254    float64
# Unnamed: 255    float64
# Length: 257, dtype: object

# %%
df.tail()
# Out:
#       index Case Number         Date  Year        Type             Country  \
# 6457   6457     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6458   6458     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6459   6459     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6460   6460     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6461   6461     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 6457  Western Australia                          Roebuck Bay        Diving
# 6458  Western Australia                                  NaN  Pearl diving
# 6459     North Carolina                       Ocracoke Inlet      Swimming
# 6460                NaN               Panama Bay 8ÂºN, 79ÂºW           NaN
# 6461   Eastern Province  Below the English fort, Trincomalee      Swimming
#
# ...

# %%
df['Type'].hist()
# Out:
# <Axes: >
